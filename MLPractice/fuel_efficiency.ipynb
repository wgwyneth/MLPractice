# %% [markdown]
# Basic Linear Regression Fuel Efficciency

# %%
Using the publicallty available AutoMPG dataset to predict fuel efficiency

# %%
# Out:
#   Cell In[3], line 1
#     pip install -q seaborn
#         ^
# SyntaxError: invalid syntax

# %%
#Already installed libraries
#!pip install matplotlib
#!pip install numpy
#!pip install pandas
#!pip install -q seaborn
# Out:
# Requirement already satisfied: matplotlib in C:\Users\wgwyn\miniconda3\Lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=9 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: numpy in C:\Users\wgwyn\miniconda3\Lib\site-packages (2.4.6)
# Requirement already satisfied: pandas in C:\Users\wgwyn\miniconda3\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\wgwyn\miniconda3\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
import seaborn as sns

np.set_printoptions(precision=3, suppress=True)

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp313-cp313-win_amd64.whl.metadata (4.5 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in C:\Users\wgwyn\miniconda3\Lib\site-packages (from tensorflow) (26.0)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow)
#   Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in C:\Users\wgwyn\miniconda3\Lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.2.1-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.81.1-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Collecting keras>=3.12.0 (from tensorflow)
#   Downloading keras-3.14.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from tensorflow) (2.4.6)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in C:\Users\wgwyn\miniconda3\Lib\site-packages (from keras>=3.12.0->tensorflow) (14.2.0)
# Collecting namex (from keras>=3.12.0->tensorflow)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.12.0->tensorflow)
#   Downloading optree-0.19.1-cp313-cp313-win_amd64.whl.metadata (32 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\wgwyn\miniconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.21.0-cp313-cp313-win_amd64.whl (351.2 MB)
#    ---------------------------------------- 0.0/351.2 MB ? eta -:--:--
#     --------------------------------------- 7.1/351.2 MB 47.9 MB/s eta 0:00:08
#    --- ------------------------------------ 26.5/351.2 MB 76.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 43.3/351.2 MB 78.5 MB/s eta 0:00:04
#    ------- -------------------------------- 63.2/351.2 MB 84.0 MB/s eta 0:00:04
#    --------- ------------------------------ 80.5/351.2 MB 84.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 98.3/351.2 MB 84.8 MB/s eta 0:00:03
#    ------------- ------------------------- 117.4/351.2 MB 86.1 MB/s eta 0:00:03
#    --------------- ----------------------- 136.1/351.2 MB 87.0 MB/s eta 0:00:03
#    ---------------- ---------------------- 152.3/351.2 MB 85.9 MB/s eta 0:00:03
#    ------------------ -------------------- 170.4/351.2 MB 86.3 MB/s eta 0:00:03
#    -------------------- ------------------ 187.7/351.2 MB 86.1 MB/s eta 0:00:02
#    ----------------------- --------------- 208.9/351.2 MB 87.8 MB/s eta 0:00:02
#    ------------------------- ------------- 226.0/351.2 MB 87.5 MB/s eta 0:00:02
#    -------------------------- ------------ 240.6/351.2 MB 86.4 MB/s eta 0:00:02
#    ---------------------------- ---------- 253.2/351.2 MB 84.8 MB/s eta 0:00:02
#    ------------------------------ -------- 271.1/351.2 MB 87.0 MB/s eta 0:00:01
#    ------------------------------- ------- 283.1/351.2 MB 84.4 MB/s eta 0:00:01
#    --------------------------------- ----- 297.5/351.2 MB 83.8 MB/s eta 0:00:01
#    ----------------------------------- --- 316.7/351.2 MB 83.5 MB/s eta 0:00:01
#    ------------------------------------- - 335.8/351.2 MB 84.4 MB/s eta 0:00:01
#    --------------------------------------  351.0/351.2 MB 85.2 MB/s eta 0:00:01
#    --------------------------------------  351.0/351.2 MB 85.2 MB/s eta 0:00:01
#    ---------------------------------------- 351.2/351.2 MB 76.3 MB/s  0:00:04
# Downloading grpcio-1.81.1-cp313-cp313-win_amd64.whl (4.9 MB)
#    ---------------------------------------- 0.0/4.9 MB ? eta -:--:--
#    ---------------------------------------- 4.9/4.9 MB 24.2 MB/s  0:00:00
# Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 46.2 MB/s  0:00:00
# Downloading ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl (212 kB)
# Downloading protobuf-7.35.1-cp310-abi3-win_amd64.whl (439 kB)
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading keras-3.14.1-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 91.6 MB/s  0:00:00
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    ----- ---------------------------------- 3.7/26.4 MB 20.6 MB/s eta 0:00:02
#    --------------- ------------------------ 10.2/26.4 MB 25.5 MB/s eta 0:00:01
#    --------------------- ------------------ 14.4/26.4 MB 24.7 MB/s eta 0:00:01
#    ------------------------------ --------- 20.4/26.4 MB 24.3 MB/s eta 0:00:01
#    ------------------------------------- -- 24.9/26.4 MB 24.7 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 23.4 MB/s  0:00:01
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-2.2.1-cp313-cp313-win_amd64.whl (80 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.1-cp313-cp313-win_amd64.whl (343 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, termcolor, protobuf, optree, opt_einsum, ml_dtypes, h5py, grpcio, google_pasta, gast, absl-py, astunparse, keras, tensorflow
#
#    -- -------------------------------------  1/17 [libclang]
#    ------- --------------------------------  3/17 [wrapt]
#    -------------- -------------------------  6/17 [optree]
#    --------------------- ------------------  9/17 [h5py]
#    ----------------------- ---------------- 10/17 [grpcio]
#    ------------------------- -------------- 11/17 [google_pasta]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ----------------------------------- ---- 15/17 [keras]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ------------------------------------- -- 16/17 [tensorflow]
#    ---------------------------------------- 17/17 [tensorflow]
#
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.81.1 h5py-3.14.0 keras-3.14.1 libclang-18.1.1 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.1 protobuf-7.35.1 tensorflow-2.21.0 termcolor-3.3.0 wrapt-2.2.1

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.21.0
